# %%
import pandas as pd

# Debemos instalar en Anaconda el paquete xlrd

data = pd.read_excel('proba.xlsx')

data.head()
# Out:
#     ev_ID    ev_ReceivingTime ev_ReceivingTimeUTC        ev_EventTime  \
# 0  479587 2018-08-06 09:45:40 2018-08-06 07:45:40 2018-08-06 07:45:40
# 1  479588 2018-08-06 09:45:57 2018-08-06 07:45:57 2018-08-06 07:45:57
# 2  479589 2018-08-06 09:45:57 2018-08-06 07:45:57 2018-08-06 07:45:57
# 3  479591 2018-08-06 09:46:05 2018-08-06 07:46:05 2018-08-06 07:46:05
# 4  479590 2018-08-06 09:46:05 2018-08-06 07:46:05 2018-08-06 07:46:05
#
#    PatientRef  BedRef  dev_ID ev_DeviceName          ev_SerialNumber  \
# 0        1483      32       2    BIG_DIPPER  00-0B-AB-04-9B-D7-5F-52
# 1        1564      26       1   Alaris CC_G               3700-07753
# 2        1564      26       1   Alaris CC_G               3700-07753
# 3        1564      26       1   Alaris CC_G               3700-07753
# 4        1564      26       1   Alaris CC_G               3700-07753
#
#    ev_DeviceNumber  ev_EventType  ev_Status  \
# 0              NaN            50        NaN
# 1             13.0            20        NaN
# 2             13.0            70        NaN
# 3             13.0            20        NaN
# 4             13.0            70        NaN
#
#                                ev_Description  \
# 0                              Sin pulso SpO2
# 1  levetiracetam - Alarm - Hold - VI: 16,7 ml
# 2                                   Occlusion
# 3          levetiracetam - Hold - VI: 16,7 ml
# 4                                   Occlusion
#
#                              ev_DescriptionLocalized  par_ID  ev_CustomData  \
# 0                                     Sin pulso SpO2       0            NaN
# 1  levetiracetam - Alarma - En espera - Volumen I...       0            NaN
# 2                                           OCLUSIÓN       0            NaN
# 3  levetiracetam - En espera - Volumen Infundido:...       0            NaN
# 4                                           OCLUSIÓN       0            NaN
#
#              ev_Code  ev_EndEvent  ev_PhysicalDeviceNumber
# 0  30048|1.3.1.30048            0                      NaN
# 1                250            0                      1.0
# 2             SYR 09            0                      1.0
# 3                251            0                      1.0
# 4             SYR 09            1                      1.0

# %%
# Eliminamos las columnas que sabemos que no van a resultar util
data1=data.drop(columns=['ev_ReceivingTime','ev_ReceivingTimeUTC','dev_ID','ev_DeviceNumber','ev_Status','ev_DescriptionLocalized','par_ID', 'ev_PhysicalDeviceNumber','ev_CustomData'], axis='1')
data1.head()
# Out:
#     ev_ID        ev_EventTime  PatientRef  BedRef ev_DeviceName  \
# 0  479587 2018-08-06 07:45:40        1483      32    BIG_DIPPER
# 1  479588 2018-08-06 07:45:57        1564      26   Alaris CC_G
# 2  479589 2018-08-06 07:45:57        1564      26   Alaris CC_G
# 3  479591 2018-08-06 07:46:05        1564      26   Alaris CC_G
# 4  479590 2018-08-06 07:46:05        1564      26   Alaris CC_G
#
#            ev_SerialNumber  ev_EventType  \
# 0  00-0B-AB-04-9B-D7-5F-52            50
# 1               3700-07753            20
# 2               3700-07753            70
# 3               3700-07753            20
# 4               3700-07753            70
#
#                                ev_Description            ev_Code  ev_EndEvent
# 0                              Sin pulso SpO2  30048|1.3.1.30048            0
# 1  levetiracetam - Alarm - Hold - VI: 16,7 ml                250            0
# 2                                   Occlusion             SYR 09            0
# 3          levetiracetam - Hold - VI: 16,7 ml                251            0
# 4                                   Occlusion             SYR 09            1

# %%
# Filtramos y eliminamos los datos (filas) que contengan determinadas condiciones:

# Datos procedentes del rack de bombas (AGW) no interesan
data2 = data1.drop(data1[data1['ev_DeviceName']=='AGW'].index)

# Datos con información de la medicación de la bomba, no relaionado con las alarmas
data3 = data2.drop(data2[(data2['ev_EventType']==10)|(data2['ev_EventType']==20)|(data2['ev_EventType']==30)].index)

# Datos que indican finalización de la alarma, sólo nos interesan las que se generan
data4 = data3.drop(data3[data3['ev_EndEvent']==1].index)

data4
# Out:
#      ev_ID        ev_EventTime  PatientRef  BedRef ev_DeviceName  \
# 0   479587 2018-08-06 07:45:40        1483      32    BIG_DIPPER
# 2   479589 2018-08-06 07:45:57        1564      26   Alaris CC_G
# 6   479593 2018-08-06 07:46:28        1568      16    BIG_DIPPER
# 7   479594 2018-08-06 07:46:38        1568      16    BIG_DIPPER
# 8   479595 2018-08-06 07:46:49        1568      16    BIG_DIPPER
# 9   479596 2018-08-06 07:47:07        1568      16    BIG_DIPPER
# 10  479597 2018-08-06 07:47:10        1568      16    BIG_DIPPER
# 12  479599 2018-08-06 07:47:25        1568      16    BIG_DIPPER
# 13  479600 2018-08-06 07:48:05        1574      38   Respironics
# 14  479601 2018-08-06 07:48:06        1568      16    BIG_DIPPER
# 16  479603 2018-08-06 07:48:14        1574      38    BIG_DIPPER
# 17  479604 2018-08-06 07:48:18        1568      16    BIG_DIPPER
# 18  479605 2018-08-06 07:48:53        1574      38    BIG_DIPPER
# 19  479606 2018-08-06 07:48:55        1580      37    BIG_DIPPER
# 20  479607 2018-08-06 07:48:57        1568      16    BIG_DIPPER
# 21  479608 2018-08-06 07:49:00        1574      38    BIG_DIPPER
# 23  479610 2018-08-06 07:49:18        1483      32    BIG_DIPPER
# 24  479611 2018-08-06 07:49:19        1580      37    BIG_DIPPER
# 26  479613 2018-08-06 07:49:48        1568      16    BIG_DIPPER
# 27  479614 2018-08-06 07:49:48        1568      16    BIG_DIPPER
# 28  479615 2018-08-06 07:49:55        1568      16    BIG_DIPPER
# 29  479616 2018-08-06 07:49:58        1568      16    BIG_DIPPER
# 30  479617 2018-08-06 07:49:59        1483      32    BIG_DIPPER
# 32  479619 2018-08-06 07:50:14        1483      32    BIG_DIPPER
# 33  479620 2018-08-06 07:50:15        1568      16    BIG_DIPPER
# 34  479621 2018-08-06 07:50:28        1586      34    BIG_DIPPER
# 35  479622 2018-08-06 07:50:33        1580      37    BIG_DIPPER
# 37  479624 2018-08-06 07:50:47        1568      16    BIG_DIPPER
# 38  479625 2018-08-06 07:51:14        1580      37    BIG_DIPPER
# 41  479628 2018-08-06 07:51:27        1568      16    BIG_DIPPER
# 42  479629 2018-08-06 07:51:34        1568      16    BIG_DIPPER
# 43  479630 2018-08-06 07:51:36        1580      37    BIG_DIPPER
# 44  479631 2018-08-06 07:51:38        1568      16    BIG_DIPPER
# 46  479633 2018-08-06 07:51:57        1483      32    BIG_DIPPER
# 47  479634 2018-08-06 07:51:59        1580      37    BIG_DIPPER
# 49  479636 2018-08-06 07:52:01        1568      16    BIG_DIPPER
# 50  479637 2018-08-06 07:52:15        1568      16    BIG_DIPPER
# 51  479638 2018-08-06 07:52:40        1568      16    BIG_DIPPER
# 52  479639 2018-08-06 07:52:44        1568      16    BIG_DIPPER
# 54  479641 2018-08-06 07:53:17        1568      16    BIG_DIPPER
# 55  479642 2018-08-06 07:53:31        1568      16    BIG_DIPPER
# 56  479643 2018-08-06 07:53:36        1568      16    BIG_DIPPER
# 57  479644 2018-08-06 07:53:45        1568      16    BIG_DIPPER
# 58  479645 2018-08-06 07:54:08        1568      16    BIG_DIPPER
# 59  479646 2018-08-06 07:54:09        1568      16    BIG_DIPPER
# 60  479647 2018-08-06 07:54:21        1568      16    BIG_DIPPER
# 61  479648 2018-08-06 07:54:24        1568      16    BIG_DIPPER
# 62  479649 2018-08-06 07:54:39        1568      16    BIG_DIPPER
#
#             ev_SerialNumber  ev_EventType                ev_Description  \
# 0   00-0B-AB-04-9B-D7-5F-52            50                Sin pulso SpO2
# 2                3700-07753            70                     Occlusion
# 6   00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 7   00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 8   00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 9   00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 10  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 12  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 13                        0            70  Frecuencia respiratoria alta
# 14  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 16  00-0B-AB-04-9B-D7-60-06            40           Perfusión baja SpO2
# 17  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 18  00-0B-AB-04-9B-D7-60-06            40           Búsqueda pulso SpO2
# 19  00-0B-AB-04-9B-D7-63-F1            60                       FR alta
# 20  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 21  00-0B-AB-04-9B-D7-60-06            40           Perfusión baja SpO2
# 23  00-0B-AB-04-9B-D7-5F-52            40           Búsqueda pulso SpO2
# 24  00-0B-AB-04-9B-D7-63-F1            60                       FR alta
# 26  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 27  00-0B-AB-04-9B-D7-63-CC            40           BIS Ground Checking
# 28  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 29  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 30  00-0B-AB-04-9B-D7-5F-52            40           Búsqueda pulso SpO2
# 32  00-0B-AB-04-9B-D7-5F-52            50                Sin pulso SpO2
# 33  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 34  00-0B-AB-04-9B-D7-63-EE            50          Manguito PANI suelto
# 35  00-0B-AB-04-9B-D7-63-F1            60                       FR alta
# 37  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 38  00-0B-AB-04-9B-D7-63-F1            60                       FR alta
# 41  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 42  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 43  00-0B-AB-04-9B-D7-63-F1            60                       FR alta
# 44  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 46  00-0B-AB-04-9B-D7-5F-52            60                     SpO2 bajo
# 47  00-0B-AB-04-9B-D7-63-F1            60                       FR alta
# 49  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 50  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 51  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 52  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 54  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 55  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 56  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 57  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 58  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 59  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 60  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 61  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
# 62  00-0B-AB-04-9B-D7-63-CC            40             Interferencia IBE
#
#                 ev_Code  ev_EndEvent
# 0     30048|1.3.1.30048            0
# 2                SYR 09            0
# 6    30522|1.12.1.30522            0
# 7    30522|1.12.1.30522            0
# 8    30522|1.12.1.30522            0
# 9    30522|1.12.1.30522            0
# 10   30522|1.12.1.30522            0
# 12   30522|1.12.1.30522            0
# 13    121|VRPT;49|MISCA            0
# 14   30522|1.12.1.30522            0
# 16    30013|1.3.1.30013            0
# 17   30522|1.12.1.30522            0
# 18    30211|1.3.1.30211            0
# 19  196652|1.7.1.151578            0
# 20   30522|1.12.1.30522            0
# 21    30013|1.3.1.30013            0
# 23    30211|1.3.1.30211            0
# 24  196652|1.7.1.151578            0
# 26   30522|1.12.1.30522            0
# 27   30533|1.12.1.30533            0
# 28   30522|1.12.1.30522            0
# 29   30522|1.12.1.30522            0
# 30    30211|1.3.1.30211            0
# 32    30048|1.3.1.30048            0
# 33   30522|1.12.1.30522            0
# 34    30223|1.1.9.30223            0
# 35  196652|1.7.1.151578            0
# 37   30522|1.12.1.30522            0
# 38  196652|1.7.1.151578            0
# 41   30522|1.12.1.30522            0
# 42   30522|1.12.1.30522            0
# 43  196652|1.7.1.151578            0
# 44   30522|1.12.1.30522            0
# 46  196674|1.3.1.150456            0
# 47  196652|1.7.1.151578            0
# 49   30522|1.12.1.30522            0
# 50   30522|1.12.1.30522            0
# 51   30522|1.12.1.30522            0
# 52   30522|1.12.1.30522            0
# 54   30522|1.12.1.30522            0
# 55   30522|1.12.1.30522            0
# 56   30522|1.12.1.30522            0
# 57   30522|1.12.1.30522            0
# 58   30522|1.12.1.30522            0
# 59   30522|1.12.1.30522            0
# 60   30522|1.12.1.30522            0
# 61   30522|1.12.1.30522            0
# 62   30522|1.12.1.30522            0

# %%
### Cambiar valores BedRef con la referencia real del servicio

# 1. Cambiamos el tipo de dato de la columna BedRef
data4['BedRef'] = data4['BedRef'].astype(str)

# bed = {15 : U01, 16:U02,17:S17,24:U04,25:U05,26:U03,27:S18,28:S19,29:S20,30:U06,31:U07,32:U08,33:U09,34:U10,35:U11,36:U12,37:U13,38:U14,39:U15,40:U16,41:U21,42:U22,43:U23,44:U24,45:U25,46:U26,47:U27,48:U28}

# 2. Creamos diccionario con valores a reemplazar (información proporcionada por el fabricante)
bed = {'15':'U01', '16':'U02','17':'S17','24':'U04','25':'U05','26':'U03','27':'S18','28':'S19','29':'S20','30':'U06','31':'U07','32':'U08','33':'U09','34':'U10','35':'U11','36':'U12','37':'U13','38':'U14','39':'U15','40':'U16','41':'U21','42':'U22','43':'U23','44':'U24','45':'U25','46':'U26','47':'U27','48':'U28'}

# 3. Realizamos el intercambio de valores
data4['BedRef'] = data4['BedRef'].apply(lambda x:bed[x])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-830c136165b8> in <module>
#      10
#      11 # 3. Realizamos el intercambio de valores
# ---> 12 data4['BedRef'] = data4['BedRef'].apply(lambda x:bed[x])
#      13
#      14
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-6-830c136165b8> in <lambda>(x)
#      10
#      11 # 3. Realizamos el intercambio de valores
# ---> 12 data4['BedRef'] = data4['BedRef'].apply(lambda x:bed[x])
#      13
#      14
#
# KeyError: 'U08'

# %%
# Observemos que clase de objetos tenemos en nuestros datos:
data4.dtypes

# Como vemos, la mayoria de valores son de tipo entero, fecha o bien "object" que es un tipo poco útil.
# Out:
# ev_ID                       int64
# ev_EventTime       datetime64[ns]
# PatientRef                  int64
# BedRef                     object
# ev_DeviceName              object
# ev_SerialNumber            object
# ev_EventType                int64
# ev_Description             object
# ev_Code                    object
# ev_EndEvent                 int64
# dtype: object

# %%
# Períodos de filtraje:
import numpy as np

filt1 = np.datetime64('2018-05-14')
filt2 = np.datetime64('2018-07-02')
filt3 = np.datetime64('')

# Extración de períodos en horas
periodo1 = (filt2)-(filt1)
print (periodo1)
# Out:
# 49 days

# %%
# Cargamos alarmas filtraje 1 Mindray

alarmsMindray1 = pd.read_excel('2018-05-14 - Alarmas_Mindray.xlsx')

alarmsMindray1.head()

# Eliminamos las columnas que sabemos que no van a resultar util
alarmsMindray1=alarmsMindray1.drop(columns=['Level','Class','Short Text','New Level','New Class','Text ENG','Text ENG Short', 'Text USER','Text USER Short'], axis='1')
alarmsMindray1.head()

# Filtramos datos "Level=0" y "Level=1"
Mindray1_alarms0 = alarmsMindray1[alarmsMindray1['Level2'] == 0]
Mindray1_alarms1 = alarmsMindray1[alarmsMindray1['Level2'] == 1]

Mindray1_alarms1.head()
# Out:
#                     Code        Text  Level2
# 7    196652|1.1.1.150037  Art-S alta       1
# 8    196652|1.1.1.150038  Art-D alta       1
# 9    196652|1.1.1.150039  Art-M alta       1
# 29   196652|1.1.1.153611  PIC-M alta       1
# 40  196652|1.11.4.151570     FR alta       1

# %%
# Cargamos alarmas filtraje 1 Bombas

alarmsBombas1 = pd.read_excel('2018-05-14 - Alarmas_Bombas.xlsx')

alarmsBombas1.head()

# Eliminamos las columnas que sabemos que no van a resultar util
alarmsBombas1=alarmsBombas1.drop(columns=['Level','Class','Short Text'], axis='1')
alarmsBombas1.head()


# Filtramos datos "Level=0" y "Level=1"
Bombas1_alarms0 = alarmsBombas1[alarmsBombas1['Level2'] == 0]
Bombas1_alarms1 = alarmsBombas1[alarmsBombas1['Level2'] == 1]

Bombas1_alarms1.head()
# Out:
#       Code                       Text  Level2
# 6      256  Pump disconnected {0} {1}       1
# 7      257     Pump connected {0} {1}       1
# 11  ENT 03              BATTERY EMPTY       1
# 12  ENT 04            END OF DELIVERY       1
# 13  ENT 05            END OF DELIVERY       1

# %%
# Cargamos alarmas filtraje 1 Respiradores (+ Prismaflex)

alarmsResp1 = pd.read_excel('2018-05-14 - Alarmas_Respiradores.xlsx')

alarmsResp1.head()


# Eliminamos las columnas que sabemos que no van a resultar util
alarmsResp1=alarmsResp1.drop(columns=['Level','Class','Short Text'], axis='1')
alarmsResp1.head()


# Filtramos datos "Level=0" y "Level=1"
Resp1_alarms0 = alarmsResp1[alarmsResp1['Level2'] == 0]
Resp1_alarms1 = alarmsResp1[alarmsResp1['Level2'] == 1]

Resp1_alarms1.head()
# Out:
#                  Code                               Text  Level2
# 0            102|VRPT                           Oclusión       1
# 7   109|VRPT;45|MISCA          Presión inspiratoria baja       1
# 12           118|VRPT             Volumen corriente bajo       1
# 13           119|VRPT  Volumen corriente espontáneo bajo       1
# 14  121|VRPT;49|MISCA       Frecuencia respiratoria alta       1

# %%
# Cálculo de estadísticos interesantes totales

# Cantidad de alarmas por código
alarms_counts = data4.groupby('ev_Code')['ev_ID'].count()
print(alarms_counts)

    # Si lo realizamos por descripción, los valores deberían ser los mismos:
alarms_counts2 = data4.groupby('ev_Description')['ev_ID'].count()
print(alarms_counts2)

# Cantidad de alarmas por boxes
alarms_counts3 = data4.groupby('BedRef')['ev_ID'].count()
print(alarms_counts3)

# Cantidad de alarmas por dispositivos (Bombas, Monitor, Respirador)
alarms_counts4 = data4.groupby('ev_DeviceName')['ev_ID'].count()
print(alarms_counts4)
# Out:
# ev_Code
# 121|VRPT;49|MISCA       1
# 196652|1.7.1.151578     6
# 196674|1.3.1.150456     1
# 30013|1.3.1.30013       2
# 30048|1.3.1.30048       2
# 30211|1.3.1.30211       3
# 30223|1.1.9.30223       1
# 30522|1.12.1.30522     30
# 30533|1.12.1.30533      1
# SYR 09                  1
# Name: ev_ID, dtype: int64
# ev_Description
# BIS Ground Checking              1
# Búsqueda pulso SpO2              3
# FR alta                          6
# Frecuencia respiratoria alta     1
# Interferencia IBE               30
# Manguito PANI suelto             1
# Occlusion                        1
# Perfusión baja SpO2              2
# Sin pulso SpO2                   2
# SpO2 bajo                        1
# Name: ev_ID, dtype: int64
# BedRef
# U02    31
# U03     1
# U08     5
# U10     1
# U13     6
# U14     4
# Name: ev_ID, dtype: int64
# ev_DeviceName
# Alaris CC_G     1
# BIG_DIPPER     46
# Respironics     1
# Name: ev_ID, dtype: int64

# %%
# Agrupamos alarmas nivel 1 de todos los dispositivos del primer filtrado

filt1_level1=pd.concat([Mindray1_alarms1,Bombas1_alarms1,Resp1_alarms1], ignore_index=True)

filt1_level1.head()
# Out:
#                    Code        Text  Level2
# 0   196652|1.1.1.150037  Art-S alta       1
# 1   196652|1.1.1.150038  Art-D alta       1
# 2   196652|1.1.1.150039  Art-M alta       1
# 3   196652|1.1.1.153611  PIC-M alta       1
# 4  196652|1.11.4.151570     FR alta       1

# %%
# Cálculo de estadísticos interesantes totales

prueba=0
for x in data4.ev_Code:
    for y in filt1_level1.Code:
        if data4.ev_Code[x]==filt1_level1.Code[y]:
            prueba=prueba+1

print(prueba)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-854955e74461> in <module>
#       4 for x in data4.ev_Code:
#       5     for y in filt1_level1.Code:
# ----> 6         if data4.ev_Code[x]==filt1_level1.Code[y]:
#       7             prueba=prueba+1
#       8
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#    3120             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: '30048|1.3.1.30048'

# %%
# Para comparar las alarmas generadas que coinciden con el primer filtraje

# Desde el codigo
import collections

for row1 in data4['ev_Code']:
    for row2 in filt1_level1['Code']:
        if row1==row2:
            code1=row1
            print(code1)
code2 = pd.DataFrame(code1, dtype=str)
cuenta1 = collections.Counter(code2)
print(cuenta1)
# Out:
# SYR 09
# 121|VRPT;49|MISCA
# 30211|1.3.1.30211
# 196652|1.7.1.151578
# 30211|1.3.1.30211
# 196652|1.7.1.151578
# 30211|1.3.1.30211
# 196652|1.7.1.151578
# 196652|1.7.1.151578
# 196652|1.7.1.151578
# 196674|1.3.1.150456
# 196652|1.7.1.151578
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-7a0992724a86> in <module>
#       9             code1=row1
#      10             print(code1)
# ---> 11 code2 = pd.DataFrame(code1, dtype=str)
#      12 cuenta1 = collections.Counter(code2)
#      13 print(cuenta1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     420                                          dtype=values.dtype, copy=False)
#     421             else:
# --> 422                 raise ValueError('DataFrame constructor not properly called!')
#     423
#     424         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
# Desde el texto

cod_a = dict()
for row1 in data4['ev_Description']:
    for row2 in filt1_level1['Text']:
        if row1==row2:
            
            text1=row1
            alarms_p=[text1]
            
print(alarms_p)

# %%
# Cantidad de alarmas por código
filt1_counts = data4.groupby('ev_Code')['ev_ID'].count()
print(filt1s_counts)

# Si lo realizamos por descripción, los valores deberían ser los mismos:
filt1_counts2 = data4.groupby('ev_Description')['ev_ID'].count()
print(filt1_counts2)

# Cantidad de alarmas por boxes
filt1_counts3 = data4.groupby('BedRef')['ev_ID'].count()
print(filt1_counts3)

# Cantidad de alarmas por dispositivos (Bombas, Monitor, Respirador)
filt1_counts4 = data4.groupby('ev_DeviceName')['ev_ID'].count()
print(filt1_counts4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-c66aedd832b0> in <module>
#       1 # Cantidad de alarmas por código
#       2 filt1_counts = data4.groupby('ev_Code')['ev_ID'].count()
# ----> 3 print(filt1s_counts)
#       4
#       5 # Si lo realizamos por descripción, los valores deberían ser los mismos:
#
# NameError: name 'filt1s_counts' is not defined
